# %% [markdown]
# Programa 7: Museo

# %%
m=3
j=16
a=17
print("Tarifas de un museo")
edad=int(input("Introduzca su edad "))
si=1
no=2
b=3
c=4
if edad<=m:
  print("El menor pasa gratis")

elif edad<=j:
  print("El joven paga $50")
  print("Presione 1 para si y 2 para no")
  estudiante=int(input("Tiene credencial de estudiante "))
  if estudiante==si:
    print("Tiene un 10% de descuento y paga $45")
  else:
    print("Usted paga $50")
     
elif edad>=a:
  print("El adulto paga $100")
  entrada=int(input("Presiene 3 cuenta con credencial de docente y 4 si tiene credencial del inapam "))
  if docente==b:
    print("Tiene un 30% de descuento y paga $70")
  elif inapam==c:
    print("Tiene un 50% de descuento y paga $50")
else:
    print("Usted paga $100")
# Out:
# Tarifas de un museo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# ...

# %% [markdown]
# Programa 8: Triangulos

# %%
t=(int(input("Introduce cuantos renglones quieres del triangulo retangulo ")))
contador=0
while contador<t:
  contador= contador+1
  print("*"*contador)
# Out:
# Introduce cuantos renglones quieres del triangulo retangulo 4
# *
# **
# ***
# ****

# %% [markdown]
# Programa 9: Factorial

# %%
f = input("Ingresa el numero que deseas saber su factorial: ")
x = int(f)
count = 1
z = 1
while z <= x:
    count = count * z
    z = z + 1
print(count)
# Out:
# Ingresa el numero que deseas saber su factorial: 4
# 24

# %% [markdown]
# Programa 10: Area de un circulo y volumen de un cilindro

# %%
n=3.1416
r=int(input("Dame el valor del radio"))
h=int(input("Dame el valor de la altura"))
v=n*pow(r,2)*h
print("El valor del volumen es ", v)
c=n*pow(r,2)
print("El area del circulo es ", c)
# Out:
# Dame el valor del radio4
# Dame el valor de la altura3
# El valor del volumen es  150.7968
# El area del circulo es  50.2656
